# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
print("""
Lane: Refresh / Content Opportunity Scoring

Why:
I chose the Refresh / Content Opportunity Scoring lane because it focuses on identifying webpages that should be reviewed before they lose search visibility. In the starter notebooks, I learned how to rank pages using both a hand-written rule and a decision tree model. Since websites can contain thousands of pages, machine learning can help prioritize which pages should be reviewed first instead of relying only on manual analysis.
""")
# Out:
# Lane: Refresh / Content Opportunity Scoring
#
# Why:
# I chose the Refresh / Content Opportunity Scoring lane because it focuses on identifying webpages that should be reviewed before they lose search visibility. In the starter notebooks, I learned how to rank pages using both a hand-written rule and a decision tree model. Since websites can contain thousands of pages, machine learning can help prioritize which pages should be reviewed first instead of relying only on manual analysis.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
print("""
Research Question:
Can machine learning identify webpages that are likely to decline so they can be reviewed before they lose search visibility?

Decision:
Which webpages should be reviewed first for content refresh?

Who takes the action?
The SEO or content team reviews and updates the highest-priority webpages.

Cost of a wrong recommendation:
If a declining page is missed, it may continue losing traffic and visibility.
If a healthy page is incorrectly flagged, the team may spend time and resources updating a page that did not need attention.
""")
# Out:
# Research Question:
# Can machine learning identify webpages that are likely to decline so they can be reviewed before they lose search visibility?
#
# Decision:
# Which webpages should be reviewed first for content refresh?
#
# Who takes the action?
# The SEO or content team reviews and updates the highest-priority webpages.
#
# Cost of a wrong recommendation:
# If a declining page is missed, it may continue losing traffic and visibility.
# If a healthy page is incorrectly flagged, the team may spend time and resources updating a page that did not need attention.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
print("""
Quick Look at the Data

• Total webpages in the starter dataset: 30,000
• Approximately 54.2% of the webpages are labelled as declining.
• The hand-written rule achieved a Precision@50 of 0.680.
• A decision tree with max_depth=3 improved Precision@50 to 0.720.

These numbers suggest that a machine learning model may help prioritize webpages for review more effectively than a simple hand-written rule.
""")
# Out:
# Quick Look at the Data
#
# • Total webpages in the starter dataset: 30,000
# • Approximately 54.2% of the webpages are labelled as declining.
# • The hand-written rule achieved a Precision@50 of 0.680.
# • A decision tree with max_depth=3 improved Precision@50 to 0.720.
#
# These numbers suggest that a machine learning model may help prioritize webpages for review more effectively than a simple hand-written rule.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
print("""
Careful Words

This project is based on observational data from the starter dataset. The analysis may identify patterns and relationships that suggest which webpages should be reviewed first, but it does not prove that refreshing a page will cause better search performance. Any recommendations should be validated through human review and further testing.
""")
# Out:
# Careful Words
#
# This project is based on observational data from the starter dataset. The analysis may identify patterns and relationships that suggest which webpages should be reviewed first, but it does not prove that refreshing a page will cause better search performance. Any recommendations should be validated through human review and further testing.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %%
print("""
Self Check

✓ I have defined a clear research question.
✓ I selected the Refresh / Content Opportunity Scoring lane.
✓ I explained the business decision my work supports.
✓ I included real observations from the starter dataset.
✓ I used careful language and avoided unsupported causal claims.
✓ I understand that this project is intended to support decision-making, not replace human judgment.
""")
# Out:
# Self Check
#
# ✓ I have defined a clear research question.
# ✓ I selected the Refresh / Content Opportunity Scoring lane.
# ✓ I explained the business decision my work supports.
# ✓ I included real observations from the starter dataset.
# ✓ I used careful language and avoided unsupported causal claims.
# ✓ I understand that this project is intended to support decision-making, not replace human judgment.
